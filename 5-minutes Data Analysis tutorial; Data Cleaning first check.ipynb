# %%
import pandas as pd
from ydata_profiling import ProfileReport
df = pd.read_csv('chocolate_bars.csv')
df.head(2)
# Out:
#      id manufacturer company_location  year_reviewed         bean_origin  \
# 0  2454         5150           U.S.A.           2019            Tanzania
# 1  2458         5150           U.S.A.           2019  Dominican Republic
#
#                 bar_name  cocoa_percent  num_ingredients ingredients  \
# 0  Kokoa Kamili, batch 1           76.0              3.0       B,S,C
# 1        Zorzal, batch 1           76.0              3.0       B,S,C
#
#                       review  rating
# 0  rich cocoa, fatty, bready    3.25
# 1     cocoa, vegetal, savory    3.50

# %%
profile = ProfileReport(df, title = 'Profile_Report')
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.5.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-10-09 10:20:14.291465&quot;&gt;&lt;title&gt;Profile_Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df.dtypes
# Out:
# id                    int64
# manufacturer         object
# company_location     object
# year_reviewed         int64
# bean_origin          object
# bar_name             object
# cocoa_percent       float64
# num_ingredients     float64
# ingredients          object
# review               object
# rating              float64
# dtype: object

# %%
#change to category; category better than object for memory optimization
df['id'] = df['id'].astype('category')
#convert year_reviewed to datetime
df['year_reviewed'] = pd.to_datetime(df['year_reviewed'])

# %%
df.dtypes
# Out:
# id                        category
# manufacturer                object
# company_location            object
# year_reviewed       datetime64[ns]
# bean_origin                 object
# bar_name                    object
# cocoa_percent              float64
# num_ingredients            float64
# ingredients                 object
# review                      object
# rating                     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2530 entries, 0 to 2529
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2530 non-null   category
#  1   manufacturer      2530 non-null   object
#  2   company_location  2530 non-null   object
#  3   year_reviewed     2530 non-null   datetime64[ns]
#  4   bean_origin       2530 non-null   object
#  5   bar_name          2530 non-null   object
#  6   cocoa_percent     2530 non-null   float64
#  7   num_ingredients   2443 non-null   float64
#  8   ingredients       2443 non-null   object
#  9   review            2530 non-null   object
#  10  rating            2530 non-null   float64
# dtypes: category(1), datetime64[ns](1), float64(3), object(6)
# memory usage: 223.8+ KB

# %% [markdown]
# ## Note: First step; data type is accurate now

# %% [markdown]
# # other conversions:
# # convert category or object to integer or float
# # df(['col_name']) = df(['col_name']).astype('int')
# # df(['col_name']) = df(['col_name']).astype('float')
